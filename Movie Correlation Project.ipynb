# %% [markdown]
# # Movie Industry

# %% [markdown]
# Importing Necessary Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib
import matplotlib.pyplot as plt
plt.style.use("ggplot")
from matplotlib import figure
# %matplotlib inline
matplotlib.rcParams["figure.figsize"] = (12,8)

# %% [markdown]
# importing Dataset
#
# Link to Dataset:https://www.kaggle.com/datasets/danielgrijalvas/movies/download?datasetVersionNumber=2

# %%
pd.set_option("display.max_rows", None)

# %%
movies = pd.read_csv("movies.csv")
movies = movies.dropna()
movies.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %% [markdown]
# Checking for missing Values

# %%
movies.isnull().sum()
# Out:
# name        0
# rating      0
# genre       0
# year        0
# released    0
# score       0
# votes       0
# director    0
# writer      0
# star        0
# country     0
# budget      0
# gross       0
# company     0
# runtime     0
# dtype: int64

# %% [markdown]
# Checking the columns Datatypes and changing them where necessary

# %%
movies.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
movies[["budget", "gross"]] = movies[["budget", "gross"]].astype("int64")

# %%
movies.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %% [markdown]
# Working on released column

# %%
released_date = movies["released"].str.split("(", expand = True, n = 2)
released_date = released_date[0]
released_date.head()
# Out:
# 0    June 13, 1980
# 1     July 2, 1980
# 2    June 20, 1980
# 3     July 2, 1980
# 4    July 25, 1980
# Name: 0, dtype: object

# %%
#Inserting it into the table back
movies.insert(loc = 4, column = "released_date", value = released_date)
movies.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#     released_date                       released  score      votes  \
# 0  June 13, 1980   June 13, 1980 (United States)    8.4   927000.0
# 1   July 2, 1980    July 2, 1980 (United States)    5.8    65000.0
# 2  June 20, 1980   June 20, 1980 (United States)    8.7  1200000.0
# 3   July 2, 1980    July 2, 1980 (United States)    7.7   221000.0
# 4  July 25, 1980   July 25, 1980 (United States)    7.3   108000.0
#
#           director                   writer            star         country  \
# ...

# %%
#Droppnig released column
movies = movies.drop(columns = "released")
movies.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#     released_date  score      votes         director                   writer  \
# 0  June 13, 1980     8.4   927000.0  Stanley Kubrick             Stephen King
# 1   July 2, 1980     5.8    65000.0   Randal Kleiser  Henry De Vere Stacpoole
# 2  June 20, 1980     8.7  1200000.0   Irvin Kershner           Leigh Brackett
# 3   July 2, 1980     7.7   221000.0     Jim Abrahams             Jim Abrahams
# 4  July 25, 1980     7.3   108000.0     Harold Ramis       Brian Doyle-Murray
#
# ...

# %%
#Adjusting the released date
movies["released_date"] = pd.to_datetime(movies["released_date"])
movies.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#   released_date  score      votes         director                   writer  \
# 0    1980-06-13    8.4   927000.0  Stanley Kubrick             Stephen King
# 1    1980-07-02    5.8    65000.0   Randal Kleiser  Henry De Vere Stacpoole
# 2    1980-06-20    8.7  1200000.0   Irvin Kershner           Leigh Brackett
# 3    1980-07-02    7.7   221000.0     Jim Abrahams             Jim Abrahams
# 4    1980-07-25    7.3   108000.0     Harold Ramis       Brian Doyle-Murray
#
# ...

# %%
#Because the year column isnt't consistent with the year from released_date
#We derive another year from released_date
Year = movies["released_date"].astype(str).str[:4]
movies.insert(loc = 4, column = "Year", value = Year)
movies.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#    Year released_date  score      votes         director  \
# 0  1980    1980-06-13    8.4   927000.0  Stanley Kubrick
# 1  1980    1980-07-02    5.8    65000.0   Randal Kleiser
# 2  1980    1980-06-20    8.7  1200000.0   Irvin Kershner
# 3  1980    1980-07-02    7.7   221000.0     Jim Abrahams
# 4  1980    1980-07-25    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000
# ...

# %%
#And drop the year column
movies = movies.drop(columns = "year")
movies.head()
# Out:
#                                              name rating      genre  Year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#   released_date  score      votes         director                   writer  \
# 0    1980-06-13    8.4   927000.0  Stanley Kubrick             Stephen King
# 1    1980-07-02    5.8    65000.0   Randal Kleiser  Henry De Vere Stacpoole
# 2    1980-06-20    8.7  1200000.0   Irvin Kershner           Leigh Brackett
# 3    1980-07-02    7.7   221000.0     Jim Abrahams             Jim Abrahams
# 4    1980-07-25    7.3   108000.0     Harold Ramis       Brian Doyle-Murray
#
# ...

# %% [markdown]
# Sorting the table

# %%
movies = movies.sort_values(by = "gross", ascending = False)
movies.head()
# Out:
#                                             name rating   genre  Year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#      released_date  score      votes       director              writer  \
# 5445    2009-12-18    7.8  1100000.0  James Cameron       James Cameron
# 7445    2019-04-26    8.4   903000.0  Anthony Russo  Christopher Markus
# 3045    1997-12-19    7.8  1100000.0  James Cameron       James Cameron
# 6663    2015-12-18    7.8   876000.0    J.J. Abrams     Lawrence Kasdan
# 7244    2018-04-27    8.4   897000.0  Anthony Russo  Christopher Markus
#
#                    star        country     budget       gross  \
# ...

# %% [markdown]
# Dropping Duplicates

# %%
movies = movies.drop_duplicates()
movies.head()
# Out:
#                                             name rating   genre  Year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#      released_date  score      votes       director              writer  \
# 5445    2009-12-18    7.8  1100000.0  James Cameron       James Cameron
# 7445    2019-04-26    8.4   903000.0  Anthony Russo  Christopher Markus
# 3045    1997-12-19    7.8  1100000.0  James Cameron       James Cameron
# 6663    2015-12-18    7.8   876000.0    J.J. Abrams     Lawrence Kasdan
# 7244    2018-04-27    8.4   897000.0  Anthony Russo  Christopher Markus
#
#                    star        country     budget       gross  \
# ...

# %% [markdown]
# Correlation between Budget and Gross

# %%
#Plotting Budget vs Gross using Matplotlib
plt.scatter(x = movies["budget"], y = movies["gross"])
plt.title("Movie Budget vs Gross Earning")
plt.xlabel("Budget (Million $)")
plt.ylabel("Gross Earning (Billion $)")
# Out:
# Text(0, 0.5, 'Gross Earning (Billion $)')

# %%
#Plotting Budget vs Gross using Seaborn
sn.regplot(x = "budget", y = "gross", data = movies, scatter_kws= {"color":"black"}, line_kws= {"color":"red"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
#Looking at the correlation
movies.corr(method = "pearson")
# Out:
#             score     votes    budget     gross   runtime
# score    1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.414068  0.352303  0.318695  0.275796  1.000000

# %% [markdown]
# Here we can see that there's High Correlation betweenn The Movie Budget and Gross Earning

# %%
#Plotting a Heatmap for the correlation
correlation_matrix = movies.corr(method = "pearson")
sn.heatmap(correlation_matrix, annot = True)
plt.title("Heatmap for Numeric Features")
plt.xlabel("Budget Features")
plt.ylabel("Gross Earning Features")
# Out:
# Text(87.0, 0.5, 'Gross Earning Features')

# %% [markdown]
# Correlation

# %%
numerized_movies = movies

for col_name in numerized_movies.columns:
    if(numerized_movies[col_name].dtype == 'object'):
        numerized_movies[col_name] = numerized_movies[col_name].astype("category")
        numerized_movies[col_name] = numerized_movies[col_name].cat.codes
numerized_movies
# Out:
#       name  rating  genre  Year released_date  score      votes  director  \
# 5445   386       5      0    29    2009-12-18    7.8  1100000.0       785
# 7445   388       5      0    39    2019-04-26    8.4   903000.0       105
# 3045  4909       5      6    17    1997-12-19    7.8  1100000.0       785
# 6663  3643       5      0    35    2015-12-18    7.8   876000.0       768
# 7244   389       5      0    38    2018-04-27    8.4   897000.0       105
# ...    ...     ...    ...   ...           ...    ...        ...       ...
# 5640  3794       6      6    35    2015-01-15    5.8     3500.0       585
# 2434  2969       5      0    14    1994-06-04    4.5     1900.0      1805
# 3681  1595       3      6    21    2001-05-11    6.8    43000.0       952
# 272   2909       6      9     2    1982-03-12    3.9     2300.0       261
# 3203  4966       5      4    17    1997-10-01    5.7     5800.0       651
#
#       writer  star  country     budget       gross  company  runtime
# ...

# %%
correlation_matrix = numerized_movies.corr()
correlation_matrix
# Out:
#               name    rating     genre      Year     score     votes  \
# name      1.000000 -0.029234  0.010996  0.025542  0.014450  0.012615
# rating   -0.029234  1.000000  0.147796  0.022021  0.065983  0.006031
# genre     0.010996  0.147796  1.000000 -0.069147  0.035106 -0.135990
# Year      0.025542  0.022021 -0.069147  1.000000  0.061923  0.203098
# score     0.014450  0.065983  0.035106  0.061923  1.000000  0.474256
# votes     0.012615  0.006031 -0.135990  0.203098  0.474256  1.000000
# director  0.015246  0.014656 -0.008553 -0.037371  0.005413 -0.010376
# writer    0.012880 -0.003149  0.017578 -0.025495  0.012843 -0.005316
# star     -0.006882  0.009196  0.003341 -0.032687  0.007296 -0.017638
# country  -0.025490  0.008230 -0.009164 -0.073569 -0.043051  0.041551
# budget    0.023392 -0.203946 -0.368523  0.320312  0.072001  0.439675
# gross     0.005639 -0.181906 -0.244101  0.268721  0.222556  0.614751
# company   0.021697 -0.092357 -0.071334 -0.018806  0.020656  0.118470
# ...

# %%
sn.heatmap(correlation_matrix, annot = True)
plt.title("Heatmap for Numeric Features")
plt.xlabel("Budget Features")
plt.ylabel("Gross Earning Features")
# Out:
# Text(87.0, 0.5, 'Gross Earning Features')

# %%
#Unstacking the Correlated Matrix
unstacked_correlation_matrix = correlation_matrix
unstacked_correlation_matrix = unstacked_correlation_matrix.unstack() 
unstacked_correlation_matrix
# Out:
# name     name       1.000000
#          rating    -0.029234
#          genre      0.010996
#          Year       0.025542
#          score      0.014450
#                       ...
# runtime  country   -0.034477
#          budget     0.318695
#          gross      0.275796
#          company    0.037585
#          runtime    1.000000
# Length: 196, dtype: float64

# %%
#Sorting the Correlated Matrix
sorted_unstacked_correlation_matrix = unstacked_correlation_matrix.sort_values()
sorted_unstacked_correlation_matrix.head()
# Out:
# genre   budget   -0.368523
# budget  genre    -0.368523
# gross   genre    -0.244101
# genre   gross    -0.244101
# budget  rating   -0.203946
# dtype: float64

# %%
#Filtering the correlated vales
unstacked_correlation_matrix[unstacked_correlation_matrix.between(0.5, 0.999999)]
# Out:
# votes   gross     0.614751
# budget  gross     0.740247
# gross   votes     0.614751
#         budget    0.740247
# dtype: float64

# %% [markdown]
# # Votes and Budget have the highest correlation to Gross Earning
